# %%
# !git clone "https://github.com/timothybrooks/instruct-pix2pix"

# %%
cd instruct-pix2pix/

# %%
# !conda env create -f environment.yaml

# %%
# !bash scripts/download_pretrained_sd.sh

# %% [markdown]
# ### **Start Generating images**
#
#
# #### `--prompts_file the jsonl` file which contains the textual dataset (can hold more than 1 row, suggested [3-5])
#
# #### `--out_dir` -> Where do you want the output iamges to be saved
#
# #### `--n-samples` -> number of images generated before filtering (suggested [60-100])
#
# #### `--max-out-samples` -> number of generated images after filtering (suggested [6-10])

# %%
# !/opt/conda/envs/ip2p/bin/python3 dataset_creation/generate_img_dataset.py --prompts_file /kaggle/input/fdddddg/part1.JSONL --out_dir data/instruct-pix2pix-dataset-000 --n-samples 60 --max-out-samples 6
# Out:
# /bin/bash: /opt/conda/envs/ip2p/bin/python3: No such file or directory

# %% [markdown]
# ### Comprese output folders into zip file to be able to download it

# %%
import shutil
shutil.make_archive('Dataset', 'zip', '/kaggle/working/instruct-pix2pix/data')
